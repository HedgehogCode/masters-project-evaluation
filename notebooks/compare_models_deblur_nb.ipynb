# %%
# %config Completer.use_jedi = False
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import seaborn as sns

# %%
METRICS_COLUMNS = ['psnr', 'ssim', 'fsim']
green_cmap = sns.light_palette('green', as_cmap=True)

# %%
df = pd.read_csv('data/deblur_nb.csv')

# Only the final result
df = df[df['Step'] == df['num_steps'] - 1].copy()

# Filter out unusable models
unusable_models = pd.read_csv('data/unusable_models.csv')['model']
df = df[~df['model'].isin(unusable_models)]

# Combine dataset and kernels name
df.loc[:, 'dataset'] = df['dataset'] + '-' + df['split']
df.loc[:, 'kernels'] = df['kernels'] + '-' + df['kernel_split']
df = df.drop(columns=['split', 'kernel_split', 'Step', 'Unnamed: 0', 'num_steps'])

# Mean over the images
df = df.groupby(['model', 'dataset', 'noise_stddev', 'algorithm']).mean()
df = df.drop(columns=['Image_Id'])
df = df.reset_index()

# %%
# List all datasets and models for usage in the next cell
print("Datasets:")
print('\n'.join(df['dataset'].unique()))
print("\nModels:")
print('\n'.join(df['model'].unique()))
print("\nNoise Stddev:")
print('\n'.join(df['noise_stddev'].astype(str).unique()))
print("\nAlgorithms:")
print('\n'.join(df['algorithm'].unique()))
# Out:
# Datasets:
# bsds500/dmsp-validation
# set5-test
#
# Models:
# dae-v01-0.05
# dae-v02-0.05
# dae-v03-0.05
# dae-v04-0.02
# dae-v04-0.05
# dae-v04-0.10
# dae-v04-0.20
# dae-v05-0.05
# dae-v06-0.10
# dae-v07-0.10
# dae-v08-0.10
# dae-v10-0.10
# dae-v11-0.05
# dae-v12-0.05
# dae-v13-0.05
# dae_0.04314
# dngan-v02-0.05
# dngan-v03-0.05
# dngan-v04-0.05
# dngan-v05-0.05
# dngan-v06-0.05
# dngan-v07-0.05
# dngan-v08-0.05
# dngan-v09-0.05
# dngan-v10-0.05
# dngan-v11-0.05
# dngan-v12-0.06
# dngan-v13-0.20
# dngan_resgen-vgg22_0.05
# dngan_resgen-vgg22_ba_0.05
# dngan_rrdb-vgg22_0.05
# drunet_0.0_0.2
# ffdgan-v01-0.0-0.2
# ffdgan-v02-0.0-0.2
# ffdgan-v03-0.0-0.2
# ffdgan-v04-0.0-0.2
# ffdgan-v05-0.0-0.2
# ffdgan-v06-0.0-0.2
# ffdnet-v01-0.0-0.2
# ffdnet-v02-0.0-0.2
# ffdnet-v03-0.0-0.2
# ffdnet-v04-0.0-0.2
#
# Noise Stddev:
# 0.01
# 0.02
# 0.03
# 0.04
#
# Algorithms:
# dmsp
# hqs

# %%
# Modify to see other results
params = {
    'dataset': 'bsds500/dmsp-validation',
    'noise_stddev': 0.04,
    'algorithm': 'dmsp',
    'model': 'dae-v04-0.10'
}

def _highlight(x):
    def rgb_for(v):
        if v == x.max():
            return (255, 255, 140)
        if v < 0.0:
            cv = (1 - (v / x.min())) * 255
            return (255, cv, cv)
        if v > 0:
            cv = (1 - (v / (x.max() / 20.0))) * 255
            return (cv, 255, cv)
        return (255, 255, 255)

    def text_color_for(v):
        r, g, b = rgb_for(v)
        lum = 0.2126*r + 0.7152*g + 0.0722*b
        if lum > 0.408:
            return 'black'
        else:
            return 'white'
    return [f'background-color: rgb{rgb_for(v)}; color: {text_color_for(v)}' for v in x]

def _filterDataset(dataset, noise_stddev, algorithm, model=None):
    d = df[df['dataset'] == dataset]
    d = d[d['noise_stddev'] == noise_stddev]
    d = d[d['algorithm'] == algorithm]
    return d.drop(['dataset', 'noise_stddev', 'algorithm'], axis=1)

def forDataset(**filters):
    d = _filterDataset(**filters)
    d = d.set_index('model')
    return d.style.background_gradient(cmap=green_cmap, subset=METRICS_COLUMNS)

def forDatasetRelative(model, **filters):
    d = _filterDataset(**filters)

    # Compute relative values
    base_row = d[d['model'] == model]
    for metric in METRICS_COLUMNS:
        base_val = base_row[metric]
        d[metric] = d[metric] - base_val.values
        
    d = d.set_index('model')
    return d.style.apply(_highlight)

forDatasetRelative(**params)
# Out:
# <style  type="text/css" >
# #T_ad018_row0_col0{
#             background-color:  rgb(255, 250.14906076954864, 250.14906076954864);
#              color:  black;
#         }#T_ad018_row0_col1{
#             background-color:  rgb(255, 253.8861079927468, 253.8861079927468);
#              color:  black;
#         }#T_ad018_row0_col2{
#             background-color:  rgb(255, 139.87468014815352, 139.87468014815352);
#              color:  black;
#         }#T_ad018_row1_col0{
#             background-color:  rgb(255, 249.95492527792783, 249.95492527792783);
#              color:  black;
#         }#T_ad018_row1_col1{
#             background-color:  rgb(255, 253.21781114694798, 253.21781114694798);
#              color:  black;
#         }#T_ad018_row1_col2{
#             background-color:  rgb(255, 139.6237423120267, 139.6237423120267);
#              color:  black;
#         }#T_ad018_row2_col0{
#             background-color:  rgb(255, 219.2712398891975, 219.2712398891975);
#              color:  black;
#         }#T_ad018_row2_col1{
#             background-color:  rgb(255, 236.1413605315664, 236.1413605315664);
#              color:  black;
#         }#T_ad018_row2_col2{
#             background-color:  rgb(255, 172.6389355367805, 172.6389355367805);
#              color:  black;
#         }#T_ad018_row3_col0{
#             background-color:  rgb(255, 92.08994212333062, 92.08994212333062);
#              color:  black;
#         }#T_ad018_row3_col1{
#             background-color:  rgb(255, 135.11608568897003, 135.11608568897003);
#              color:  black;
#         }#T_ad018_row3_col2{
#             background-color:  rgb(255, 55.726611627071605, 55.726611627071605);
#              color:  black;
#         }#T_ad018_row4_col0{
#             background-color:  rgb(255, 246.1793162860982, 246.1793162860982);
#              color:  black;
#         }#T_ad018_row4_col1{
#             background-color:  rgb(255, 248.97569837208917, 248.97569837208917);
#              color:  black;
#         }#T_ad018_row4_col2{
#             background-color:  rgb(255, 147.92729015785707, 147.92729015785707);
#              color:  black;
#         }#T_ad018_row5_col0,#T_ad018_row20_col1,#T_ad018_row41_col2{
#             background-color:  rgb(255, 255, 140);
#              color:  black;
#         }#T_ad018_row5_col1,#T_ad018_row5_col2{
#             background-color:  rgb(255, 255, 255);
#              color:  black;
#         }#T_ad018_row6_col0{
#             background-color:  rgb(255, 210.53714035316693, 210.53714035316693);
#              color:  black;
#         }#T_ad018_row6_col1{
#             background-color:  rgb(255, 182.05384222663918, 182.05384222663918);
#              color:  black;
#         }#T_ad018_row6_col2{
#             background-color:  rgb(255, 237.50716798877602, 237.50716798877602);
#              color:  black;
#         }#T_ad018_row7_col0{
#             background-color:  rgb(255, 230.9865199941346, 230.9865199941346);
#              color:  black;
#         }#T_ad018_row7_col1{
#             background-color:  rgb(255, 225.41850962888745, 225.41850962888745);
#              color:  black;
#         }#T_ad018_row7_col2{
#             background-color:  rgb(255, 149.36298124514124, 149.36298124514124);
#              color:  black;
#         }#T_ad018_row8_col0{
#             background-color:  rgb(255, 251.81769012726798, 251.81769012726798);
#              color:  black;
#         }#T_ad018_row8_col1{
#             background-color:  rgb(255, 252.65311267783432, 252.65311267783432);
#              color:  black;
#         }#T_ad018_row8_col2{
#             background-color:  rgb(255, 251.190199408674, 251.190199408674);
#              color:  black;
#         }#T_ad018_row9_col0{
#             background-color:  rgb(255, 251.15218584325237, 251.15218584325237);
#              color:  black;
#         }#T_ad018_row9_col1{
#             background-color:  rgb(255, 253.842328770328, 253.842328770328);
#              color:  black;
#         }#T_ad018_row9_col2{
#             background-color:  rgb(255, 251.6702776404875, 251.6702776404875);
#              color:  black;
#         }#T_ad018_row10_col0{
#             background-color:  rgb(255, 233.45496124892583, 233.45496124892583);
#              color:  black;
#         }#T_ad018_row10_col1{
#             background-color:  rgb(255, 251.84158701329036, 251.84158701329036);
#              color:  black;
#         }#T_ad018_row10_col2{
#             background-color:  rgb(255, 227.79254769070863, 227.79254769070863);
#              color:  black;
#         }#T_ad018_row11_col0{
#             background-color:  rgb(255, 250.00465345039345, 250.00465345039345);
#              color:  black;
#         }#T_ad018_row11_col1{
#             background-color:  rgb(255, 253.29479070658948, 253.29479070658948);
#              color:  black;
#         }#T_ad018_row11_col2{
#             background-color:  rgb(255, 247.3620462040059, 247.3620462040059);
#              color:  black;
#         }#T_ad018_row12_col0{
#             background-color:  rgb(255, 239.89078548417635, 239.89078548417635);
#              color:  black;
#         }#T_ad018_row12_col1{
#             background-color:  rgb(255, 248.43332861867523, 248.43332861867523);
#              color:  black;
#         }#T_ad018_row12_col2{
#             background-color:  rgb(255, 135.46354935046767, 135.46354935046767);
#              color:  black;
#         }#T_ad018_row13_col0{
#             background-color:  rgb(255, 239.75033419999164, 239.75033419999164);
#              color:  black;
#         }#T_ad018_row13_col1{
#             background-color:  rgb(255, 248.1099357322036, 248.1099357322036);
#              color:  black;
#         }#T_ad018_row13_col2{
#             background-color:  rgb(255, 134.5924238492905, 134.5924238492905);
#              color:  black;
#         }#T_ad018_row14_col0{
#             background-color:  rgb(255, 206.69307487072888, 206.69307487072888);
#              color:  black;
#         }#T_ad018_row14_col1{
#             background-color:  rgb(255, 251.3456512979501, 251.3456512979501);
#              color:  black;
#         }#T_ad018_row14_col2{
#             background-color:  rgb(255, 128.92108026889784, 128.92108026889784);
#              color:  black;
#         }#T_ad018_row15_col0{
#             background-color:  rgb(255, 247.59536455259402, 247.59536455259402);
#              color:  black;
#         }#T_ad018_row15_col1{
#             background-color:  rgb(255, 251.51728563476934, 251.51728563476934);
#              color:  black;
#         }#T_ad018_row15_col2{
#             background-color:  rgb(255, 121.59060698831769, 121.59060698831769);
#              color:  black;
#         }#T_ad018_row16_col0{
#             background-color:  rgb(255, 72.57047193130278, 72.57047193130278);
#              color:  black;
#         }#T_ad018_row16_col1{
#             background-color:  rgb(255, 71.03079408024205, 71.03079408024205);
#              color:  black;
#         }#T_ad018_row16_col2{
#             background-color:  rgb(255, 74.9202379283154, 74.9202379283154);
#              color:  black;
#         }#T_ad018_row17_col0{
#             background-color:  rgb(255, 122.7275512957744, 122.7275512957744);
#              color:  black;
#         }#T_ad018_row17_col1{
#             background-color:  rgb(255, 114.6500714264762, 114.6500714264762);
#              color:  black;
#         }#T_ad018_row17_col2{
#             background-color:  rgb(255, 144.91063130940245, 144.91063130940245);
#              color:  black;
#         }#T_ad018_row18_col0{
#             background-color:  rgb(255, 52.078983022738235, 52.078983022738235);
#              color:  black;
#         }#T_ad018_row18_col1{
#             background-color:  rgb(255, 93.55768217907934, 93.55768217907934);
#              color:  black;
#         }#T_ad018_row18_col2,#T_ad018_row26_col0,#T_ad018_row26_col1{
#             background-color:  rgb(255, 0.0, 0.0);
#              color:  black;
#         }#T_ad018_row19_col0{
#             background-color:  rgb(255, 164.3202612821367, 164.3202612821367);
#              color:  black;
#         }#T_ad018_row19_col1{
#             background-color:  rgb(255, 192.9786408175146, 192.9786408175146);
#              color:
