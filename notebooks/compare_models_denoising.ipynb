# %%
# %config Completer.use_jedi = False
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import seaborn as sns

# %%
METRICS_COLUMNS = ['psnr', 'ssim', 'fsim']
green_cmap = sns.light_palette('green', as_cmap=True)

# %%
df = pd.read_csv('data/denoising_evaluation.csv')

# Drop unused columns
df = df[['Model', 'Dataset', *METRICS_COLUMNS]]

# Mean over the images
df = df.groupby(['Dataset', 'Model']).mean()
#df = df.drop('Image_Id', axis=1)
df = df.reset_index()

# %%
# List all datasets and models for usage in the next cell
print("Datasets:")
print('\n'.join(df['Dataset'].unique()))
print("\nModels:")
print('\n'.join(df['Model'].unique()))
# Out:
# Datasets:
# bsds500/gauss_0.01
# bsds500/gauss_0.02
# bsds500/gauss_0.05
# bsds500/gauss_0.10
# bsds500/gauss_0.20
# set14/gauss_0.01
# set14/gauss_0.02
# set14/gauss_0.05
# set14/gauss_0.10
# set14/gauss_0.20
# set5/gauss_0.01
# set5/gauss_0.02
# set5/gauss_0.05
# set5/gauss_0.10
# set5/gauss_0.20
#
# Models:
# dae-v01-0.05
# dae-v02-0.05
# dae-v03-0.05
# dae-v04-0.02
# dae-v04-0.05
# dae-v04-0.10
# dae-v04-0.20
# dae-v05-0.05
# dae-v06-0.10
# dae-v07-0.10
# dae-v08-0.10
# dae-v10-0.10
# dae_0.04314
# dngan-v01-0.05
# dngan-v02-0.05
# dngan-v03-0.05
# dngan-v04-0.05
# dngan-v05-0.05
# dngan-v06-0.05
# dngan-v07-0.05
# dngan-v08-0.05
# dngan-v09-0.05
# dngan-v10-0.05
# dngan-v11-0.05
# dngan-v12-0.06
# dngan-v13-0.20
# dngan_resgen-vgg22_0.05
# dngan_resgen-vgg22_ba_0.05
# dngan_rrdb-vgg22_0.05
# drunet_0.0_0.2
# ffdgan-v01-0.0-0.2
# ffdgan-v02-0.0-0.2
# ffdgan-v03-0.0-0.2
# ffdgan-v04-0.0-0.2
# ffdgan-v05-0.0-0.2
# ffdgan-v06-0.0-0.2
# ffdnet-v01-0.0-0.2
# ffdnet-v02-0.0-0.2
# ffdnet-v03-0.0-0.2
# ffdnet-v04-0.0-0.2

# %%
# Modify to see other results
params = {
    'dataset': 'bsds500/gauss_0.05',
    'model': 'drunet_0.0_0.2'
}


def _highlight(x):
    def rgb_for(v):
        if v == x.max():
            return (255, 255, 140)
        if v < 0.0:
            cv = (1 - (v / x.min())) * 255
            return (255, cv, cv)
        if v > 0:
            cv = (1 - (v / (x.max() / 20.0))) * 255
            return (cv, 255, cv)
        return (255, 255, 255)

    def text_color_for(v):
        r, g, b = rgb_for(v)
        lum = 0.2126*r + 0.7152*g + 0.0722*b
        if lum > 0.408:
            return 'black'
        else:
            return 'white'
    return [f'background-color: rgb{rgb_for(v)}; color: {text_color_for(v)}' for v in x]

def _filterDataset(dataset, model=None):
    d = df[df['Dataset'] == dataset]
    return d.drop('Dataset', axis=1)

def forDataset(**filters):
    d = _filterDataset(**filters)
    d = d.set_index('Model')
    return d.style.background_gradient(cmap=green_cmap, subset=METRICS_COLUMNS)

def forDatasetRelative(dataset, model):
    d = _filterDataset(dataset)

    # Compute relative values
    base_row = d[d['Model'] == model]
    for metric in METRICS_COLUMNS:
        base_val = base_row[metric]
        d[metric] = d[metric] - base_val.values
        
    d = d.set_index('Model')
    return d.style.apply(_highlight)

forDatasetRelative(**params)
# Out:
# <style  type="text/css" >
# #T_74e63_row0_col0{
#             background-color:  rgb(255, 242.5868854275036, 242.5868854275036);
#              color:  black;
#         }#T_74e63_row0_col1{
#             background-color:  rgb(255, 249.63350237491102, 249.63350237491102);
#              color:  black;
#         }#T_74e63_row0_col2{
#             background-color:  rgb(255, 252.98020040386066, 252.98020040386066);
#              color:  black;
#         }#T_74e63_row1_col0{
#             background-color:  rgb(255, 245.50006866952714, 245.50006866952714);
#              color:  black;
#         }#T_74e63_row1_col1{
#             background-color:  rgb(255, 251.14218224396816, 251.14218224396816);
#              color:  black;
#         }#T_74e63_row1_col2{
#             background-color:  rgb(255, 253.27217550940023, 253.27217550940023);
#              color:  black;
#         }#T_74e63_row2_col0{
#             background-color:  rgb(255, 202.45309702984588, 202.45309702984588);
#              color:  black;
#         }#T_74e63_row2_col1{
#             background-color:  rgb(255, 227.1477845370606, 227.1477845370606);
#              color:  black;
#         }#T_74e63_row2_col2{
#             background-color:  rgb(255, 251.17877974922632, 251.17877974922632);
#              color:  black;
#         }#T_74e63_row3_col0{
#             background-color:  rgb(255, 65.10181040409961, 65.10181040409961);
#              color:  black;
#         }#T_74e63_row3_col1{
#             background-color:  rgb(255, 108.76462587708987, 108.76462587708987);
#              color:  black;
#         }#T_74e63_row3_col2{
#             background-color:  rgb(255, 223.5310098951836, 223.5310098951836);
#              color:  black;
#         }#T_74e63_row4_col0{
#             background-color:  rgb(255, 228.9503947861929, 228.9503947861929);
#              color:  black;
#         }#T_74e63_row4_col1{
#             background-color:  rgb(255, 243.13949532263518, 243.13949532263518);
#              color:  black;
#         }#T_74e63_row4_col2{
#             background-color:  rgb(255, 252.53240218791555, 252.53240218791555);
#              color:  black;
#         }#T_74e63_row5_col0{
#             background-color:  rgb(255, 131.78102565231072, 131.78102565231072);
#              color:  black;
#         }#T_74e63_row5_col1{
#             background-color:  rgb(255, 144.78287882653842, 144.78287882653842);
#              color:  black;
#         }#T_74e63_row5_col2{
#             background-color:  rgb(255, 138.86060085459644, 138.86060085459644);
#              color:  black;
#         }#T_74e63_row6_col0,#T_74e63_row6_col1,#T_74e63_row6_col2{
#             background-color:  rgb(255, 0.0, 0.0);
#              color:  black;
#         }#T_74e63_row7_col0{
#             background-color:  rgb(255, 205.36741291096186, 205.36741291096186);
#              color:  black;
#         }#T_74e63_row7_col1{
#             background-color:  rgb(255, 226.5072695997237, 226.5072695997237);
#              color:  black;
#         }#T_74e63_row7_col2{
#             background-color:  rgb(255, 246.4504817809134, 246.4504817809134);
#              color:  black;
#         }#T_74e63_row8_col0{
#             background-color:  rgb(255, 126.41159998328098, 126.41159998328098);
#              color:  black;
#         }#T_74e63_row8_col1{
#             background-color:  rgb(255, 143.3317005314711, 143.3317005314711);
#              color:  black;
#         }#T_74e63_row8_col2{
#             background-color:  rgb(255, 142.1733349142046, 142.1733349142046);
#              color:  black;
#         }#T_74e63_row9_col0{
#             background-color:  rgb(255, 114.65792983337225, 114.65792983337225);
#              color:  black;
#         }#T_74e63_row9_col1{
#             background-color:  rgb(255, 122.35707207642741, 122.35707207642741);
#              color:  black;
#         }#T_74e63_row9_col2{
#             background-color:  rgb(255, 144.98026318060522, 144.98026318060522);
#              color:  black;
#         }#T_74e63_row10_col0{
#             background-color:  rgb(255, 66.12634216087392, 66.12634216087392);
#              color:  black;
#         }#T_74e63_row10_col1{
#             background-color:  rgb(255, 133.85498318069799, 133.85498318069799);
#              color:  black;
#         }#T_74e63_row10_col2{
#             background-color:  rgb(255, 152.86085117791853, 152.86085117791853);
#              color:  black;
#         }#T_74e63_row11_col0{
#             background-color:  rgb(255, 32.92440504368527, 32.92440504368527);
#              color:  black;
#         }#T_74e63_row11_col1{
#             background-color:  rgb(255, 96.02972961221768, 96.02972961221768);
#              color:  black;
#         }#T_74e63_row11_col2{
#             background-color:  rgb(255, 148.54365821430963, 148.54365821430963);
#              color:  black;
#         }#T_74e63_row12_col0{
#             background-color:  rgb(255, 221.6664992690079, 221.6664992690079);
#              color:  black;
#         }#T_74e63_row12_col1{
#             background-color:  rgb(255, 234.66390682313585, 234.66390682313585);
#              color:  black;
#         }#T_74e63_row12_col2{
#             background-color:  rgb(255, 254.7368470171796, 254.7368470171796);
#              color:  black;
#         }#T_74e63_row13_col0{
#             background-color:  rgb(255, 6.0639883572721685, 6.0639883572721685);
#              color:  black;
#         }#T_74e63_row13_col1{
#             background-color:  rgb(255, 170.06476254140767, 170.06476254140767);
#              color:  black;
#         }#T_74e63_row13_col2{
#             background-color:  rgb(255, 226.846237732313, 226.846237732313);
#              color:  black;
#         }#T_74e63_row14_col0{
#             background-color:  rgb(255, 111.03810241945133, 111.03810241945133);
#              color:  black;
#         }#T_74e63_row14_col1{
#             background-color:  rgb(255, 202.67130116334616, 202.67130116334616);
#              color:  black;
#         }#T_74e63_row14_col2{
#             background-color:  rgb(255, 231.83885299679255, 231.83885299679255);
#              color:  black;
#         }#T_74e63_row15_col0{
#             background-color:  rgb(255, 93.1021976817577, 93.1021976817577);
#              color:  black;
#         }#T_74e63_row15_col1{
#             background-color:  rgb(255, 212.25540068106693, 212.25540068106693);
#              color:  black;
#         }#T_74e63_row15_col2{
#             background-color:  rgb(255, 244.6747998830166, 244.6747998830166);
#              color:  black;
#         }#T_74e63_row16_col0{
#             background-color:  rgb(255, 202.9072046336854, 202.9072046336854);
#              color:  black;
#         }#T_74e63_row16_col1{
#             background-color:  rgb(255, 235.7534069607881, 235.7534069607881);
#              color:  black;
#         }#T_74e63_row16_col2{
#             background-color:  rgb(255, 250.3029221444472, 250.3029221444472);
#              color:  black;
#         }#T_74e63_row17_col0{
#             background-color:  rgb(255, 188.18083121878036, 188.18083121878036);
#              color:  black;
#         }#T_74e63_row17_col1{
#             background-color:  rgb(255, 221.88549131440868, 221.88549131440868);
#              color:  black;
#         }#T_74e63_row17_col2{
#             background-color:  rgb(255, 233.73950287566794, 233.73950287566794);
#              color:  black;
#         }#T_74e63_row18_col0{
#             background-color:  rgb(255, 234.01482430389268, 234.01482430389268);
#              color:  black;
#         }#T_74e63_row18_col1{
#             background-color:  rgb(255, 242.58076915947603, 242.58076915947603);
#              color:  black;
#         }#T_74e63_row18_col2{
#             background-color:  rgb(255, 249.79176381286425, 249.79176381286425);
#              color:  black;
#         }#T_74e63_row19_col0{
#             background-color:  rgb(255, 228.58324224112462, 228.58324224112462);
#              color:  black;
#         }#T_74e63_row19_col1{
#             background-color:  rgb(255, 243.96891763454863, 243.96891763454863);
#              color:  black;
#         }#T_74e63_row19_col2{
#             background-color:  rgb(255, 253.79307773990877, 253.79307773990877);
